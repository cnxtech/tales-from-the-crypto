# %% [markdown]
# # News Headlines Sentiment
#
# Use the news api to pull the latest news articles for bitcoin and ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %matplotlib inline
# Out:
# In /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.frameon rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
# In /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The verbose.level rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
# In /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The verbose.fileo rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.

# %%
# Read your api key environment variable
load_dotenv()
api_key = os.getenv("NEWS_API_KEY2")

# %%
# Create a newsapi client
from newsapi import NewsApiClient
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
bitcoin_news = newsapi.get_everything(q="bitcoin", language="en")
bitcoin_articles = bitcoin_news["articles"]

# %%
# Fetch the Ethereum news articles
ethereum_news = newsapi.get_everything(q="ethereum", language="en")
ethereum_articles = ethereum_news["articles"]

# %%
# Create the Bitcoin sentiment scores DataFrame
bitcoin_corpus=[]
counter=0
for article in bitcoin_articles:
    bitcoin_corpus.append(bitcoin_articles[counter]["content"])
    counter+=1

bitcoin_corpus_df = pd.DataFrame({
    "text": bitcoin_corpus
})


# Create dictionary to hold sentiment scores
bitcoin_sentiment = {
    "Compound": [],
    "Negative": [],
    "Neutral": [],
    "Positive": []
}

# Perform sentiment analysis on Bitcoin articles
for row in bitcoin_corpus_df.iterrows():
    bitcoin_analysis = analyzer.polarity_scores(row[1]["text"])
    bitcoin_sentiment["Compound"].append(bitcoin_analysis["compound"])
    bitcoin_sentiment["Negative"].append(bitcoin_analysis["neg"])
    bitcoin_sentiment["Neutral"].append(bitcoin_analysis["neu"])
    bitcoin_sentiment["Positive"].append(bitcoin_analysis["pos"])

# Joining sentiment analysis 
bitcoin_analysis_df = pd.DataFrame.from_dict(bitcoin_sentiment)
bitcoin_df = pd.concat([bitcoin_analysis_df, bitcoin_corpus_df], axis=1)  
bitcoin_df.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0    0.0772     0.000    0.961     0.039
# 1    0.5859     0.000    0.873     0.127
# 2    0.3182     0.000    0.935     0.065
# 3    0.2023     0.000    0.950     0.050
# 4    0.6075     0.102    0.719     0.178
#
#                                                 text
# 0  Whether youre looking to make a larger investm...
# 1  As it promised earlier this year, Tesla now ac...
# 2  The inevitable has happened: You can now purch...
# 3  Tesla made headlines earlier this year when it...
# 4  National Burrito Day lands on April Fools Day ...

# %%
# Create the ethereum sentiment scores DataFrame
ethereum_corpus=[]
counter=0
for article in ethereum_articles:
    ethereum_corpus.append(ethereum_articles[counter]["content"])
    counter+=1

ethereum_corpus_df = pd.DataFrame({
    "text" : ethereum_corpus
})

# Create dictionary to hold sentiment scores
ethereum_sentiment = {
    "Compound": [],
    "Negative": [],
    "Neutral": [],
    "Positive": []
}

# Perform sentiment analysis on Ethereum articles
for row in ethereum_corpus_df.iterrows():
    ethereum_analysis = analyzer.polarity_scores(row[1]["text"])
    ethereum_sentiment["Compound"].append(ethereum_analysis["compound"])
    ethereum_sentiment["Negative"].append(ethereum_analysis["neg"])
    ethereum_sentiment["Neutral"].append(ethereum_analysis["neu"])
    ethereum_sentiment["Positive"].append(ethereum_analysis["pos"])

ethereum_analysis_df = pd.DataFrame(ethereum_sentiment)
ethereum_df = pd.concat([ethereum_analysis_df,ethereum_corpus_df], axis=1)
ethereum_df.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0   -0.5574     0.110    0.890     0.000
# 1    0.0772     0.000    0.961     0.039
# 2    0.0000     0.000    1.000     0.000
# 3    0.0000     0.000    1.000     0.000
# 4    0.5650     0.093    0.735     0.172
#
#                                                 text
# 0  One of the strictest crackdowns worldwide\r\nP...
# 1  Whether youre looking to make a larger investm...
# 2  Famed auction house Christies just sold its fi...
# 3  Payment card network Visa has announced that t...
# 4  The NFT craze has been an intriguing moment fo...

# %%
# Describe the Bitcoin Sentiment
bitcoin_df.describe()
# Out:
#         Compound   Negative    Neutral   Positive
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.205990   0.028250   0.898150   0.073600
# std     0.365651   0.047327   0.082379   0.067474
# min    -0.557400   0.000000   0.709000   0.000000
# 25%     0.000000   0.000000   0.863250   0.029250
# 50%     0.307100   0.000000   0.925500   0.065500
# 75%     0.366350   0.054500   0.940250   0.085500
# max     0.771700   0.142000   1.000000   0.240000

# %%
# Describe the Ethereum Sentiment
ethereum_df.describe()
# Out:
#         Compound   Negative    Neutral   Positive
# count  20.000000  20.000000  20.000000  20.000000
# mean   -0.012240   0.041950   0.919950   0.038150
# std     0.301147   0.047487   0.080009   0.050393
# min    -0.557400   0.000000   0.735000   0.000000
# 25%    -0.250000   0.000000   0.905750   0.000000
# 50%     0.000000   0.021000   0.934000   0.000000
# 75%     0.058000   0.080750   1.000000   0.071750
# max     0.565000   0.145000   1.000000   0.172000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Bitcoin
#
# Q: Which coin had the highest compound score?
#
# A: Bitcoin
#
# Q. Which coin had the highest positive score?
#
# A: Bitcoin

# %% [markdown]
# ---

# %% [markdown]
# # Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word
# 2. Remove Punctuation
# 3. Remove Stopwords

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Expand the default stopwords list if necessary
sw_addon = {'youre', 'whether', 'said', 'also', 'like', 'seen', 'chars', 'arent', 'according', 'first', 'one', 'make', 'allowed', 'got', 'made'}

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    sw = set(stopwords.words('english'))
    lemmatizer = WordNetLemmatizer()
    regex = re.compile("[^a-zA-Z ]")
    # Remove punctuation
    text_clean = [regex.sub('', text)]
    # Tokenize words
    word_tokenized = [word_tokenize(i) for i in text_clean]
    # Convert the words to lowercase and remove stop words
    lower_tokenized = [word.lower() for words in word_tokenized for word in words if word.lower() not in sw.union(sw_addon)]
    print(lower_tokenized)
    # Lemmatize Words into root words
    tokens = [lemmatizer.lemmatize(word) for word in lower_tokenized]
    return tokens

# %%
# Create a new tokens column for bitcoin
bitcoin_tokens = [tokenizer(article) for article in bitcoin_corpus]
bitcoin_df["tokens"] = bitcoin_tokens
# Out:
# ['looking', 'larger', 'investment', 'want', 'dabble', 'cryptocurrencies', 'purchase', 'bitcoin', 'ethereum', 'bitcoin', 'cash', 'litecoin', 'paypal', 'soon', 'youll', 'ab']
# ['promised', 'earlier', 'year', 'tesla', 'accepts', 'payment', 'bitcoin', 'teslas', 'website', 'tweet', 'ceo', 'elon', 'musk', 'subsequent', 'tweet', 'musk', 'bitcoin', 'paid', 'tesla']
# ['inevitable', 'happened', 'purchase', 'tesla', 'vehicle', 'bitcointhis', 'tesla', 'ceo', 'pardon', 'technoking', 'elon', 'musk', 'tweeted', 'wednesdayyou', 'buy', 'tesla']
# ['tesla', 'headlines', 'earlier', 'year', 'took', 'significant', 'holdings', 'bitcoin', 'acquiring', 'roughly', 'billion', 'stake', 'thenprices', 'early', 'february', 'time', 'noted', 'sec']
# ['national', 'burrito', 'day', 'lands', 'april', 'fools', 'day', 'year', 'thankfully', 'restaurants', 'playing', 'around', 'deals', 'starting', 'tomorrow', 'restaurants', 'pollo', 'loco', 'moes', 'southwest', 'grill']
# ['strictest', 'crackdowns', 'worldwidephoto', 'michele', 'doying', 'vergeindia', 'reportedly', 'moving', 'forward', 'sweeping', 'ban', 'cryptocurrencies', 'reuters', 'countrys', 'legislat']
# ['hacker', 'behind', 'last', 'years', 'big', 'twitter', 'hack', 'sentenced', 'hard', 'timegraham', 'ivan', 'clark', 'teenage', 'hacker', 'broke', 'twitters', 'systems', 'took', 'verified', 'accounts', 'used']
# ['seems', 'everyone', 'making', 'money', 'nfts', 'nonfungible', 'tokens', 'digital', 'artworks', 'labeled', 'next', 'investment', 'mania', 'everyone', 'except', 'fe']
# ['data', 'centers', 'bitcoin', 'mining', 'operations', 'becoming', 'huge', 'energy', 'hogs', 'explosive', 'growth', 'risks', 'undoing', 'lot', 'progress', 'thats', 'reduce', 'global', 'greenhouse', 'gas', 'emission']
# ['proposed', 'law', 'india', 'would', 'crime', 'mine', 'trade', 'even', 'hold', 'cryptocurrencies', 'bitcoin', 'country', 'new', 'report', 'reuters', 'citing', 'senior', 'government', 'official']
# ['big', 'year', 'crypto', 'robinhood', 'shared', 'stats', 'today', 'providing', 'evidence', 'crypto', 'boom', 'hype', 'least', 'nowin', 'blog', 'christine', 'brown', 'robinhoods', 'h']
# ['reuters', 'staffreuters', 'microstrategy', 'inc', 'major', 'bitcoin', 'corporate', 'backer', 'monday', 'nonemployee', 'directors', 'get', 'fees', 'services', 'bitcoin', 'instead', 'cashshares', 'th']
# ['paypal', 'morning', 'announced', 'launch', 'checkout', 'crypto', 'new', 'feature', 'allow', 'consumers', 'check', 'millions', 'online', 'businesses', 'using', 'cryptocurrency', 'feature', 'expands', 'pa']
# ['reuters', 'staffapril', 'reuters', 'microstrategy', 'inc', 'major', 'bitcoin', 'corporate', 'backer', 'monday', 'nonemployee', 'directors', 'get', 'fees', 'services', 'bitcoin', 'instead', 'cash', 'r']
# ['nonfungible', 'tokens', 'taking', 'collectibles', 'digital', 'realm', 'funko', 'eager', 'seize', 'company', 'bought', 'control', 'nft', 'startup', 'tokenwave', 'aim']
# ['march', 'min', 'readthis', 'article', 'translated', 'spanish', 'edition', 'using', 'ai', 'technologies', 'errors', 'may', 'exist', 'due', 'processafter', 'analyzing', 'history', 'growth', 'bitcoin', 'exp']
# ['wise', 'origin', 'bitcoin', 'etf', 'latest', 'entrant', 'growing', 'race', 'launch', 'bitcoin', 'exchangetraded', 'product', 'united', 'states', 'filing', 'firm', 'called', 'fd', 'funds', 'management', 'llc']
# ['reuters', 'stafffile', 'photo', 'representation', 'virtual', 'currency', 'bitcoin', 'us', 'dollar', 'banknotes', 'front', 'stock', 'graph', 'illustration', 'taken', 'january', 'reutersdado', 'ru']
# ['reuters', 'stafffile', 'photo', 'representations', 'virtual', 'currency', 'bitcoin', 'us', 'dollar', 'banknotes', 'picture', 'illustration', 'taken', 'january', 'reutersdado', 'ruvicillustrationreu']
# ['posted', 'paypal', 'says', 'started', 'letting', 'customers', 'use', 'bitcoin', 'checkout', 'marking', 'latest', 'sign', 'mainstream', 'financial', 'firms', 'moving', 'accept', 'cryptocurrencies', 'julian', 'satterthwaite', 'repo']

# %%
# Create a new tokens column for ethereum
ethereum_tokens = [tokenizer(article) for article in ethereum_corpus]
ethereum_df["tokens"] = ethereum_tokens
# Out:
# ['strictest', 'crackdowns', 'worldwidephoto', 'michele', 'doying', 'vergeindia', 'reportedly', 'moving', 'forward', 'sweeping', 'ban', 'cryptocurrencies', 'reuters', 'countrys', 'legislat']
# ['looking', 'larger', 'investment', 'want', 'dabble', 'cryptocurrencies', 'purchase', 'bitcoin', 'ethereum', 'bitcoin', 'cash', 'litecoin', 'paypal', 'soon', 'youll', 'ab']
# ['famed', 'auction', 'house', 'christies', 'sold', 'purely', 'digital', 'piece', 'art', 'whopping', 'million', 'price', 'buyer', 'digital', 'file', 'collage', 'images', 'complex', 'legac']
# ['payment', 'card', 'network', 'visa', 'announced', 'transactions', 'settled', 'using', 'usd', 'coin', 'usdc', 'stablecoin', 'powered', 'ethereum', 'blockchain', 'cryptocom', 'company', 'test', 'new', 'capabi']
# ['nft', 'craze', 'intriguing', 'moment', 'digital', 'artists', 'great', 'leaps', 'tech', 'create', 'work', 'much', 'progress', 'shifting', 'profit']
# ['move', 'fast', 'break', 'things', 'get', 'hackedthats', 'happened', 'roll', 'social', 'currency', 'platform', 'allows', 'creators', 'mint', 'distribute', 'ethereumbased', 'cryptocurrency', 'known', 'social']
# ['heres', 'everything', 'need', 'know', 'nonfungible', 'tokens', 'latest', 'cryptocurrency', 'crazeread', 'full', 'story', 'learn', 'even', 'nfts']
# ['opensea', 'handful', 'nft', 'marketplaces', 'explode', 'popularity', 'recent', 'weeks', 'collectors', 'wade', 'trading', 'nonfungible', 'tokens', 'blockchain', 'new', 'startups']
# ['metamask', 'popular', 'web', 'wallets', 'cryptocurrency', 'platform', 'ethereum', 'went', 'mobile', 'ios', 'android', 'september', 'however', 'mobile', 'version', 'wasnt', 'updated', 'pace', 'th']
# ['security', 'breach', 'cryptocurrency', 'platform', 'roll', 'hacker', 'obtain', 'private', 'key', 'hot', 'wallet', 'steal', 'contents', 'worth', 'millionin', 'statement', 'company', 'wa']
# ['big', 'year', 'crypto', 'robinhood', 'shared', 'stats', 'today', 'providing', 'evidence', 'crypto', 'boom', 'hype', 'least', 'nowin', 'blog', 'christine', 'brown', 'robinhoods', 'h']
# ['march', 'min', 'readthis', 'article', 'translated', 'spanish', 'edition', 'using', 'ai', 'technologies', 'errors', 'may', 'exist', 'due', 'processthe', 'iconic', 'new', 'york', 'times', 'daily', 'auctioned', 'newspaper']
# ['nonfungible', 'tokens', 'nfts', 'quickly', 'becoming', 'gotos', 'digital', 'collecting', 'includes', 'something', 'might', 'kid', 'baseball', 'cards', 'topps', 'launching', 'nftbased', 'base']
# ['tldr', 'quantinsti', 'quantitative', 'trading', 'beginners', 'bundle', 'sale', 'april', 'saving', 'list', 'pricewhether', 'purchasing', 'drinks', 'bar', 'managing', 'finan']
# ['last', 'month', 'hours', 'news', 'beeples', 'million', 'nft', 'sale', 'grabbed', 'front', 'pages', 'newspapers', 'across', 'country', 'pair', 'x', 'pixel', 'portraits', 'aliens', 'wearing', 'little', 'hats', 'sold', 'separatel']
# ['mlb', 'answer', 'nbas', 'top', 'shot', 'nft', 'clipsmajor', 'league', 'baseball', 'announced', 'latest', 'move', 'cash', 'nft', 'craze', 'official', 'blockchainbased', 'versions', 'classic', 'topps', 'baseball', 'ca']
# ['proposed', 'law', 'india', 'would', 'crime', 'mine', 'trade', 'even', 'hold', 'cryptocurrencies', 'bitcoin', 'country', 'new', 'report', 'reuters', 'citing', 'senior', 'government', 'official']
# ['damien', 'hirst', 'famous', 'pickling', 'sharks', 'encrusting', 'skulls', 'diamondschris', 'younggetty', 'imagessuperstar', 'artist', 'damien', 'hirst', 'set', 'become', 'biggest', 'player', 'yet', 'enter', 'world', 'n']
# ['cryptocurrency', 'ether', 'runs', 'ethereum', 'networkdado', 'ruvicreutersullithe', 'price', 'ether', 'surged', 'alltime', 'high', 'friday', 'lockstep', 'bitcoins', 'rally', 'shy', 'li']
# ['lately', 'ive', 'taken', 'greatly', 'epaper', 'tablet', 'remarkable', 'im', 'sure', 'sells', 'apple', 'amazon', 'slower', 'monochrome', 'less', 'powerful', 'ipad', 'somehow', 'duller', 'pape']

# %% [markdown]
# ---

# %% [markdown]
# # NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
bitcoin_words = []
for word in bitcoin_tokens:
    bitcoin_words.extend(word)
bitcoin_ngrams = Counter(ngrams(bitcoin_words, n=2))
dict(bitcoin_ngrams)
# Out:
# {('looking', 'larger'): 1,
#  ('larger', 'investment'): 1,
#  ('investment', 'want'): 1,
#  ('want', 'dabble'): 1,
#  ('dabble', 'cryptocurrencies'): 1,
#  ('cryptocurrencies', 'purchase'): 1,
#  ('purchase', 'bitcoin'): 1,
#  ('bitcoin', 'ethereum'): 1,
#  ('ethereum', 'bitcoin'): 1,
#  ('bitcoin', 'cash'): 1,
#  ('cash', 'litecoin'): 1,
#  ('litecoin', 'paypal'): 1,
#  ('paypal', 'soon'): 1,
#  ('soon', 'youll'): 1,
#  ('youll', 'ab'): 1,
#  ('ab', 'promised'): 1,
#  ('promised', 'earlier'): 1,
#  ('earlier', 'year'): 2,
#  ('year', 'tesla'): 1,
#  ('tesla', 'accepts'): 1,
#  ('accepts', 'payment'): 1,
#  ('payment', 'bitcoin'): 1,
#  ('bitcoin', 'tesla'): 1,
#  ('tesla', 'website'): 1,
#  ('website', 'tweet'): 1,
#  ('tweet', 'ceo'): 1,
#  ('ceo', 'elon'): 1,
#  ('elon', 'musk'): 2,
#  ('musk', 'subsequent'): 1,
#  ('subsequent', 'tweet'): 1,
#  ('tweet', 'musk'): 1,
#  ('musk', 'bitcoin'): 1,
#  ('bitcoin', 'paid'): 1,
#  ('paid', 'tesla'): 1,
#  ('tesla', 'inevitable'): 1,
#  ('inevitable', 'happened'): 1,
#  ('happened', 'purchase'): 1,
#  ('purchase', 'tesla'): 1,
#  ('tesla', 'vehicle'): 1,
#  ('vehicle', 'bitcointhis'): 1,
#  ('bitcointhis', 'tesla'): 1,
#  ('tesla', 'ceo'): 1,
#  ('ceo', 'pardon'): 1,
#  ('pardon', 'technoking'): 1,
#  ('technoking', 'elon'): 1,
#  ('musk', 'tweeted'): 1,
#  ('tweeted', 'wednesdayyou'): 1,
#  ('wednesdayyou', 'buy'): 1,
#  ('buy', 'tesla'): 1,
#  ('tesla', 'tesla'): 1,
#  ('tesla', 'headline'): 1,
#  ('headline', 'earlier'): 1,
#  ('year', 'took'): 1,
#  ('took', 'significant'): 1,
#  ('significant', 'holding'): 1,
#  ('holding', 'bitcoin'): 1,
#  ('bitcoin', 'acquiring'): 1,
#  ('acquiring', 'roughly'): 1,
#  ('roughly', 'billion'): 1,
#  ('billion', 'stake'): 1,
#  ('stake', 'thenprices'): 1,
#  ('thenprices', 'early'): 1,
#  ('early', 'february'): 1,
#  ('february', 'time'): 1,
#  ('time', 'noted'): 1,
#  ('noted', 'sec'): 1,
#  ('sec', 'national'): 1,
#  ('national', 'burrito'): 1,
#  ('burrito', 'day'): 1,
#  ('day', 'land'): 1,
#  ('land', 'april'): 1,
#  ('april', 'fool'): 1,
#  ('fool', 'day'): 1,
#  ('day', 'year'): 1,
#  ('year', 'thankfully'): 1,
#  ('thankfully', 'restaurant'): 1,
#  ('restaurant', 'playing'): 1,
#  ('playing', 'around'): 1,
#  ('around', 'deal'): 1,
#  ('deal', 'starting'): 1,
#  ('starting', 'tomorrow'): 1,
#  ('tomorrow', 'restaurant'): 1,
#  ('restaurant', 'pollo'): 1,
#  ('pollo', 'loco'): 1,
#  ('loco', 'moes'): 1,
#  ('moes', 'southwest'): 1,
#  ('southwest', 'grill'): 1,
#  ('grill', 'strictest'): 1,
#  ('strictest', 'crackdown'): 1,
#  ('crackdown', 'worldwidephoto'): 1,
#  ('worldwidephoto', 'michele'): 1,
#  ('michele', 'doying'): 1,
#  ('doying', 'vergeindia'): 1,
#  ('vergeindia', 'reportedly'): 1,
#  ('reportedly', 'moving'): 1,
#  ('moving', 'forward'): 1,
#  ('forward', 'sweeping'): 1,
#  ('sweeping', 'ban'): 1,
#  ('ban', 'cryptocurrencies'): 1,
#  ('cryptocurrencies', 'reuters'): 1,
#  ('reuters', 'country'): 1,
#  ('country', 'legislat'): 1,
#  ('legislat', 'hacker'): 1,
#  ('hacker', 'behind'): 1,
#  ('behind', 'last'): 1,
#  ('last', 'year'): 1,
#  ('year', 'big'): 1,
#  ('big', 'twitter'): 1,
#  ('twitter', 'hack'): 1,
#  ('hack', 'sentenced'): 1,
#  ('sentenced', 'hard'): 1,
#  ('hard', 'timegraham'): 1,
#  ('timegraham', 'ivan'): 1,
#  ('ivan', 'clark'): 1,
#  ('clark', 'teenage'): 1,
#  ('teenage', 'hacker'): 1,
#  ('hacker', 'broke'): 1,
#  ('broke', 'twitter'): 1,
#  ('twitter', 'system'): 1,
#  ('system', 'took'): 1,
#  ('took', 'verified'): 1,
#  ('verified', 'account'): 1,
#  ('account', 'used'): 1,
#  ('used', 'seems'): 1,
#  ('seems', 'everyone'): 1,
#  ('everyone', 'making'): 1,
#  ('making', 'money'): 1,
#  ('money', 'nfts'): 1,
#  ('nfts', 'nonfungible'): 1,
#  ('nonfungible', 'token'): 2,
#  ('token', 'digital'): 1,
#  ('digital', 'artwork'): 1,
#  ('artwork', 'labeled'): 1,
#  ('labeled', 'next'): 1,
#  ('next', 'investment'): 1,
#  ('investment', 'mania'): 1,
#  ('mania', 'everyone'): 1,
#  ('everyone', 'except'): 1,
#  ('except', 'fe'): 1,
#  ('fe', 'data'): 1,
#  ('data', 'center'): 1,
#  ('center', 'bitcoin'): 1,
#  ('bitcoin', 'mining'): 1,
#  ('mining', 'operation'): 1,
#  ('operation', 'becoming'): 1,
#  ('becoming', 'huge'): 1,
#  ('huge', 'energy'): 1,
#  ('energy', 'hog'): 1,
#  ('hog', 'explosive'): 1,
#  ('explosive', 'growth'): 1,
#  ('growth', 'risk'): 1,
#  ('risk', 'undoing'): 1,
#  ('undoing', 'lot'): 1,
#  ('lot', 'progress'): 1,
#  ('progress', 'thats'): 1,
#  ('thats', 'reduce'): 1,
#  ('reduce', 'global'): 1,
#  ('global', 'greenhouse'): 1,
#  ('greenhouse', 'gas'): 1,
#  ('gas', 'emission'): 1,
#  ('emission', 'proposed'): 1,
#  ('proposed', 'law'): 1,
#  ('law', 'india'): 1,
#  ('india', 'would'): 1,
#  ('would', 'crime'): 1,
#  ('crime', 'mine'): 1,
#  ('mine', 'trade'): 1,
#  ('trade', 'even'): 1,
#  ('even', 'hold'): 1,
#  ('hold', 'cryptocurrencies'): 1,
#  ('cryptocurrencies', 'bitcoin'): 1,
#  ('bitcoin', 'country'): 1,
#  ('country', 'new'): 1,
#  ('new', 'report'): 1,
#  ('report', 'reuters'): 1,
#  ('reuters', 'citing'): 1,
#  ('citing', 'senior'): 1,
#  ('senior', 'government'): 1,
#  ('government', 'official'): 1,
#  ('official', 'big'): 1,
#  ('big', 'year'): 1,
#  ('year', 'crypto'): 1,
#  ('crypto', 'robinhood'): 1,
#  ('robinhood', 'shared'): 1,
#  ('shared', 'stats'): 1,
#  ('stats', 'today'): 1,
#  ('today', 'providing'): 1,
#  ('providing', 'evidence'): 1,
#  ('evidence', 'crypto'): 1,
#  ('crypto', 'boom'): 1,
#  ('boom', 'hype'): 1,
#  ('hype', 'least'): 1,
#  ('least', 'nowin'): 1,
#  ('nowin', 'blog'): 1,
#  ('blog', 'christine'): 1,
#  ('christine', 'brown'): 1,
#  ('brown', 'robinhoods'): 1,
#  ('robinhoods', 'h'): 1,
#  ('h', 'reuters'): 1,
#  ('reuters', 'staffreuters'): 1,
#  ('staffreuters', 'microstrategy'): 1,
#  ('microstrategy', 'inc'): 2,
#  ('inc', 'major'): 2,
#  ('major', 'bitcoin'): 2,
#  ('bitcoin', 'corporate'): 2,
#  ('corporate', 'backer'): 2,
#  ('backer', 'monday'): 2,
#  ('monday', 'nonemployee'): 2,
#  ('nonemployee', 'director'): 2,
#  ('director', 'get'): 2,
#  ('get', 'fee'): 2,
#  ('fee', 'service'): 2,
#  ('service', 'bitcoin'): 2,
#  ('bitcoin', 'instead'): 2,
#  ('instead', 'cashshares'): 1,
#  ('cashshares', 'th'): 1,
#  ('th', 'paypal'): 1,
#  ('paypal', 'morning'): 1,
#  ('morning', 'announced'): 1,
#  ('announced', 'launch'): 1,
#  ('launch', 'checkout'): 1,
#  ('checkout', 'crypto'): 1,
#  ('crypto', 'new'): 1,
#  ('new', 'feature'): 1,
#  ('feature', 'allow'): 1,
#  ('allow', 'consumer'): 1,
#  ('consumer', 'check'): 1,
#  ('check', 'million'): 1,
#  ('million', 'online'): 1,
#  ('online', 'business'): 1,
#  ('business', 'using'): 1,
#  ('using', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'feature'): 1,
#  ('feature', 'expands'): 1,
#  ('expands', 'pa'): 1,
#  ('pa', 'reuters'): 1,
#  ('reuters', 'staffapril'): 1,
#  ('staffapril', 'reuters'): 1,
#  ('reuters', 'microstrategy'): 1,
#  ('instead', 'cash'): 1,
#  ('cash', 'r'): 1,
#  ('r', 'nonfungible'): 1,
#  ('token', 'taking'): 1,
#  ('taking', 'collectible'): 1,
#  ('collectible', 'digital'): 1,
#  ('digital', 'realm'): 1,
#  ('realm', 'funko'): 1,
#  ('funko', 'eager'): 1,
#  ('eager', 'seize'): 1,
#  ('seize', 'company'): 1,
#  ('company', 'bought'): 1,
#  ('bought', 'control'): 1,
#  ('control', 'nft'): 1,
#  ('nft', 'startup'): 1,
#  ('startup', 'tokenwave'): 1,
#  ('tokenwave', 'aim'): 1,
#  ('aim', 'march'): 1,
#  ('march', 'min'): 1,
#  ('min', 'readthis'): 1,
#  ('readthis', 'article'): 1,
#  ('article', 'translated'): 1,
#  ('translated', 'spanish'): 1,
#  ('spanish', 'edition'): 1,
#  ('edition', 'using'): 1,
#  ('using', 'ai'): 1,
#  ('ai', 'technology'): 1,
#  ('technology', 'error'): 1,
#  ('error', 'may'): 1,
#  ('may', 'exist'): 1,
#  ('exist', 'due'): 1,
#  ('due', 'processafter'): 1,
#  ('processafter', 'analyzing'): 1,
#  ('analyzing', 'history'): 1,
#  ('history', 'growth'): 1,
#  ('growth', 'bitcoin'): 1,
#  ('bitcoin', 'exp'): 1,
#  ('exp', 'wise'): 1,
#  ('wise', 'origin'): 1,
#  ('origin', 'bitcoin'): 1,
#  ('bitcoin', 'etf'): 1,
#  ('etf', 'latest'): 1,
#  ('latest', 'entrant'): 1,
#  ('entrant', 'growing'): 1,
#  ('growing', 'race'): 1,
#  ('race', 'launch'): 1,
#  ('launch', 'bitcoin'): 1,
#  ('bitcoin', 'exchangetraded'): 1,
#  ('exchangetraded', 'product'): 1,
#  ('product', 'united'): 1,
#  ('united', 'state'): 1,
#  ('state', 'filing'): 1,
#  ('filing', 'firm'): 1,
#  ('firm', 'called'): 1,
#  ('called', 'fd'): 1,
#  ('fd', 'fund'): 1,
#  ('fund', 'management'): 1,
#  ('management', 'llc'): 1,
#  ('llc', 'reuters'): 1,
#  ('reuters', 'stafffile'): 2,
#  ('stafffile', 'photo'): 2,
#  ('photo', 'representation'): 2,
#  ('representation', 'virtual'): 2,
#  ('virtual', 'currency'): 2,
#  ('currency', 'bitcoin'): 2,
#  ('bitcoin', 'u'): 2,
#  ('u', 'dollar'): 2,
#  ('dollar', 'banknote'): 2,
#  ('banknote', 'front'): 1,
#  ('front', 'stock'): 1,
#  ('stock', 'graph'): 1,
#  ('graph', 'illustration'): 1,
#  ('illustration', 'taken'): 2,
#  ('taken', 'january'): 2,
#  ('january', 'reutersdado'): 2,
#  ('reutersdado', 'ru'): 1,
#  ('ru', 'reuters'): 1,
#  ('banknote', 'picture'): 1,
#  ('picture', 'illustration'): 1,
#  ('reutersdado', 'ruvicillustrationreu'): 1,
#  ('ruvicillustrationreu', 'posted'): 1,
#  ('posted', 'paypal'): 1,
#  ('paypal', 'say'): 1,
#  ('say', 'started'): 1,
#  ('started', 'letting'): 1,
#  ('letting', 'customer'): 1,
#  ('customer', 'use'): 1,
#  ('use', 'bitcoin'): 1,
#  ('bitcoin', 'checkout'): 1,
#  ('checkout', 'marking'): 1,
#  ('marking', 'latest'): 1,
#  ('latest', 'sign'): 1,
#  ('sign', 'mainstream'): 1,
#  ('mainstream', 'financial'): 1,
#  ('financial', 'firm'): 1,
#  ('firm', 'moving'): 1,
#  ('moving', 'accept'): 1,
#  ('accept', 'cryptocurrencies'): 1,
#  ('cryptocurrencies', 'julian'): 1,
#  ('julian', 'satterthwaite'): 1,
#  ('satterthwaite', 'repo'): 1}

# %%
# Generate the Ethereum N-grams where N=2
ethereum_words = []
for word in ethereum_tokens:
    ethereum_words.extend(word)
ethereum_ngrams = Counter(ngrams(ethereum_words, n=2))
dict(ethereum_ngrams)
# Out:
# {('strictest', 'crackdown'): 1,
#  ('crackdown', 'worldwidephoto'): 1,
#  ('worldwidephoto', 'michele'): 1,
#  ('michele', 'doying'): 1,
#  ('doying', 'vergeindia'): 1,
#  ('vergeindia', 'reportedly'): 1,
#  ('reportedly', 'moving'): 1,
#  ('moving', 'forward'): 1,
#  ('forward', 'sweeping'): 1,
#  ('sweeping', 'ban'): 1,
#  ('ban', 'cryptocurrencies'): 1,
#  ('cryptocurrencies', 'reuters'): 1,
#  ('reuters', 'country'): 1,
#  ('country', 'legislat'): 1,
#  ('legislat', 'looking'): 1,
#  ('looking', 'larger'): 1,
#  ('larger', 'investment'): 1,
#  ('investment', 'want'): 1,
#  ('want', 'dabble'): 1,
#  ('dabble', 'cryptocurrencies'): 1,
#  ('cryptocurrencies', 'purchase'): 1,
#  ('purchase', 'bitcoin'): 1,
#  ('bitcoin', 'ethereum'): 1,
#  ('ethereum', 'bitcoin'): 1,
#  ('bitcoin', 'cash'): 1,
#  ('cash', 'litecoin'): 1,
#  ('litecoin', 'paypal'): 1,
#  ('paypal', 'soon'): 1,
#  ('soon', 'youll'): 1,
#  ('youll', 'ab'): 1,
#  ('ab', 'famed'): 1,
#  ('famed', 'auction'): 1,
#  ('auction', 'house'): 1,
#  ('house', 'christie'): 1,
#  ('christie', 'sold'): 1,
#  ('sold', 'purely'): 1,
#  ('purely', 'digital'): 1,
#  ('digital', 'piece'): 1,
#  ('piece', 'art'): 1,
#  ('art', 'whopping'): 1,
#  ('whopping', 'million'): 1,
#  ('million', 'price'): 1,
#  ('price', 'buyer'): 1,
#  ('buyer', 'digital'): 1,
#  ('digital', 'file'): 1,
#  ('file', 'collage'): 1,
#  ('collage', 'image'): 1,
#  ('image', 'complex'): 1,
#  ('complex', 'legac'): 1,
#  ('legac', 'payment'): 1,
#  ('payment', 'card'): 1,
#  ('card', 'network'): 1,
#  ('network', 'visa'): 1,
#  ('visa', 'announced'): 1,
#  ('announced', 'transaction'): 1,
#  ('transaction', 'settled'): 1,
#  ('settled', 'using'): 1,
#  ('using', 'usd'): 1,
#  ('usd', 'coin'): 1,
#  ('coin', 'usdc'): 1,
#  ('usdc', 'stablecoin'): 1,
#  ('stablecoin', 'powered'): 1,
#  ('powered', 'ethereum'): 1,
#  ('ethereum', 'blockchain'): 1,
#  ('blockchain', 'cryptocom'): 1,
#  ('cryptocom', 'company'): 1,
#  ('company', 'test'): 1,
#  ('test', 'new'): 1,
#  ('new', 'capabi'): 1,
#  ('capabi', 'nft'): 1,
#  ('nft', 'craze'): 2,
#  ('craze', 'intriguing'): 1,
#  ('intriguing', 'moment'): 1,
#  ('moment', 'digital'): 1,
#  ('digital', 'artist'): 1,
#  ('artist', 'great'): 1,
#  ('great', 'leap'): 1,
#  ('leap', 'tech'): 1,
#  ('tech', 'create'): 1,
#  ('create', 'work'): 1,
#  ('work', 'much'): 1,
#  ('much', 'progress'): 1,
#  ('progress', 'shifting'): 1,
#  ('shifting', 'profit'): 1,
#  ('profit', 'move'): 1,
#  ('move', 'fast'): 1,
#  ('fast', 'break'): 1,
#  ('break', 'thing'): 1,
#  ('thing', 'get'): 1,
#  ('get', 'hackedthats'): 1,
#  ('hackedthats', 'happened'): 1,
#  ('happened', 'roll'): 1,
#  ('roll', 'social'): 1,
#  ('social', 'currency'): 1,
#  ('currency', 'platform'): 1,
#  ('platform', 'allows'): 1,
#  ('allows', 'creator'): 1,
#  ('creator', 'mint'): 1,
#  ('mint', 'distribute'): 1,
#  ('distribute', 'ethereumbased'): 1,
#  ('ethereumbased', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'known'): 1,
#  ('known', 'social'): 1,
#  ('social', 'here'): 1,
#  ('here', 'everything'): 1,
#  ('everything', 'need'): 1,
#  ('need', 'know'): 1,
#  ('know', 'nonfungible'): 1,
#  ('nonfungible', 'token'): 3,
#  ('token', 'latest'): 1,
#  ('latest', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'crazeread'): 1,
#  ('crazeread', 'full'): 1,
#  ('full', 'story'): 1,
#  ('story', 'learn'): 1,
#  ('learn', 'even'): 1,
#  ('even', 'nfts'): 1,
#  ('nfts', 'opensea'): 1,
#  ('opensea', 'handful'): 1,
#  ('handful', 'nft'): 1,
#  ('nft', 'marketplace'): 1,
#  ('marketplace', 'explode'): 1,
#  ('explode', 'popularity'): 1,
#  ('popularity', 'recent'): 1,
#  ('recent', 'week'): 1,
#  ('week', 'collector'): 1,
#  ('collector', 'wade'): 1,
#  ('wade', 'trading'): 1,
#  ('trading', 'nonfungible'): 1,
#  ('token', 'blockchain'): 1,
#  ('blockchain', 'new'): 1,
#  ('new', 'startup'): 1,
#  ('startup', 'metamask'): 1,
#  ('metamask', 'popular'): 1,
#  ('popular', 'web'): 1,
#  ('web', 'wallet'): 1,
#  ('wallet', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'platform'): 2,
#  ('platform', 'ethereum'): 1,
#  ('ethereum', 'went'): 1,
#  ('went', 'mobile'): 1,
#  ('mobile', 'io'): 1,
#  ('io', 'android'): 1,
#  ('android', 'september'): 1,
#  ('september', 'however'): 1,
#  ('however', 'mobile'): 1,
#  ('mobile', 'version'): 1,
#  ('version', 'wasnt'): 1,
#  ('wasnt', 'updated'): 1,
#  ('updated', 'pace'): 1,
#  ('pace', 'th'): 1,
#  ('th', 'security'): 1,
#  ('security', 'breach'): 1,
#  ('breach', 'cryptocurrency'): 1,
#  ('platform', 'roll'): 1,
#  ('roll', 'hacker'): 1,
#  ('hacker', 'obtain'): 1,
#  ('obtain', 'private'): 1,
#  ('private', 'key'): 1,
#  ('key', 'hot'): 1,
#  ('hot', 'wallet'): 1,
#  ('wallet', 'steal'): 1,
#  ('steal', 'content'): 1,
#  ('content', 'worth'): 1,
#  ('worth', 'millionin'): 1,
#  ('millionin', 'statement'): 1,
#  ('statement', 'company'): 1,
#  ('company', 'wa'): 1,
#  ('wa', 'big'): 1,
#  ('big', 'year'): 1,
#  ('year', 'crypto'): 1,
#  ('crypto', 'robinhood'): 1,
#  ('robinhood', 'shared'): 1,
#  ('shared', 'stats'): 1,
#  ('stats', 'today'): 1,
#  ('today', 'providing'): 1,
#  ('providing', 'evidence'): 1,
#  ('evidence', 'crypto'): 1,
#  ('crypto', 'boom'): 1,
#  ('boom', 'hype'): 1,
#  ('hype', 'least'): 1,
#  ('least', 'nowin'): 1,
#  ('nowin', 'blog'): 1,
#  ('blog', 'christine'): 1,
#  ('christine', 'brown'): 1,
#  ('brown', 'robinhoods'): 1,
#  ('robinhoods', 'h'): 1,
#  ('h', 'march'): 1,
#  ('march', 'min'): 1,
#  ('min', 'readthis'): 1,
#  ('readthis', 'article'): 1,
#  ('article', 'translated'): 1,
#  ('translated', 'spanish'): 1,
#  ('spanish', 'edition'): 1,
#  ('edition', 'using'): 1,
#  ('using', 'ai'): 1,
#  ('ai', 'technology'): 1,
#  ('technology', 'error'): 1,
#  ('error', 'may'): 1,
#  ('may', 'exist'): 1,
#  ('exist', 'due'): 1,
#  ('due', 'processthe'): 1,
#  ('processthe', 'iconic'): 1,
#  ('iconic', 'new'): 1,
#  ('new', 'york'): 1,
#  ('york', 'time'): 1,
#  ('time', 'daily'): 1,
#  ('daily', 'auctioned'): 1,
#  ('auctioned', 'newspaper'): 1,
#  ('newspaper', 'nonfungible'): 1,
#  ('token', 'nfts'): 1,
#  ('nfts', 'quickly'): 1,
#  ('quickly', 'becoming'): 1,
#  ('becoming', 'gotos'): 1,
#  ('gotos', 'digital'): 1,
#  ('digital', 'collecting'): 1,
#  ('collecting', 'includes'): 1,
#  ('includes', 'something'): 1,
#  ('something', 'might'): 1,
#  ('might', 'kid'): 1,
#  ('kid', 'baseball'): 1,
#  ('baseball', 'card'): 1,
#  ('card', 'topps'): 1,
#  ('topps', 'launching'): 1,
#  ('launching', 'nftbased'): 1,
#  ('nftbased', 'base'): 1,
#  ('base', 'tldr'): 1,
#  ('tldr', 'quantinsti'): 1,
#  ('quantinsti', 'quantitative'): 1,
#  ('quantitative', 'trading'): 1,
#  ('trading', 'beginner'): 1,
#  ('beginner', 'bundle'): 1,
#  ('bundle', 'sale'): 1,
#  ('sale', 'april'): 1,
#  ('april', 'saving'): 1,
#  ('saving', 'list'): 1,
#  ('list', 'pricewhether'): 1,
#  ('pricewhether', 'purchasing'): 1,
#  ('purchasing', 'drink'): 1,
#  ('drink', 'bar'): 1,
#  ('bar', 'managing'): 1,
#  ('managing', 'finan'): 1,
#  ('finan', 'last'): 1,
#  ('last', 'month'): 1,
#  ('month', 'hour'): 1,
#  ('hour', 'news'): 1,
#  ('news', 'beeples'): 1,
#  ('beeples', 'million'): 1,
#  ('million', 'nft'): 1,
#  ('nft', 'sale'): 1,
#  ('sale', 'grabbed'): 1,
#  ('grabbed', 'front'): 1,
#  ('front', 'page'): 1,
#  ('page', 'newspaper'): 1,
#  ('newspaper', 'across'): 1,
#  ('across', 'country'): 1,
#  ('country', 'pair'): 1,
#  ('pair', 'x'): 1,
#  ('x', 'pixel'): 1,
#  ('pixel', 'portrait'): 1,
#  ('portrait', 'alien'): 1,
#  ('alien', 'wearing'): 1,
#  ('wearing', 'little'): 1,
#  ('little', 'hat'): 1,
#  ('hat', 'sold'): 1,
#  ('sold', 'separatel'): 1,
#  ('separatel', 'mlb'): 1,
#  ('mlb', 'answer'): 1,
#  ('answer', 'nbas'): 1,
#  ('nbas', 'top'): 1,
#  ('top', 'shot'): 1,
#  ('shot', 'nft'): 1,
#  ('nft', 'clipsmajor'): 1,
#  ('clipsmajor', 'league'): 1,
#  ('league', 'baseball'): 1,
#  ('baseball', 'announced'): 1,
#  ('announced', 'latest'): 1,
#  ('latest', 'move'): 1,
#  ('move', 'cash'): 1,
#  ('cash', 'nft'): 1,
#  ('craze', 'official'): 1,
#  ('official', 'blockchainbased'): 1,
#  ('blockchainbased', 'version'): 1,
#  ('version', 'classic'): 1,
#  ('classic', 'topps'): 1,
#  ('topps', 'baseball'): 1,
#  ('baseball', 'ca'): 1,
#  ('ca', 'proposed'): 1,
#  ('proposed', 'law'): 1,
#  ('law', 'india'): 1,
#  ('india', 'would'): 1,
#  ('would', 'crime'): 1,
#  ('crime', 'mine'): 1,
#  ('mine', 'trade'): 1,
#  ('trade', 'even'): 1,
#  ('even', 'hold'): 1,
#  ('hold', 'cryptocurrencies'): 1,
#  ('cryptocurrencies', 'bitcoin'): 1,
#  ('bitcoin', 'country'): 1,
#  ('country', 'new'): 1,
#  ('new', 'report'): 1,
#  ('report', 'reuters'): 1,
#  ('reuters', 'citing'): 1,
#  ('citing', 'senior'): 1,
#  ('senior', 'government'): 1,
#  ('government', 'official'): 1,
#  ('official', 'damien'): 1,
#  ('damien', 'hirst'): 2,
#  ('hirst', 'famous'): 1,
#  ('famous', 'pickling'): 1,
#  ('pickling', 'shark'): 1,
#  ('shark', 'encrusting'): 1,
#  ('encrusting', 'skull'): 1,
#  ('skull', 'diamondschris'): 1,
#  ('diamondschris', 'younggetty'): 1,
#  ('younggetty', 'imagessuperstar'): 1,
#  ('imagessuperstar', 'artist'): 1,
#  ('artist', 'damien'): 1,
#  ('hirst', 'set'): 1,
#  ('set', 'become'): 1,
#  ('become', 'biggest'): 1,
#  ('biggest', 'player'): 1,
#  ('player', 'yet'): 1,
#  ('yet', 'enter'): 1,
#  ('enter', 'world'): 1,
#  ('world', 'n'): 1,
#  ('n', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'ether'): 1,
#  ('ether', 'run'): 1,
#  ('run', 'ethereum'): 1,
#  ('ethereum', 'networkdado'): 1,
#  ('networkdado', 'ruvicreutersullithe'): 1,
#  ('ruvicreutersullithe', 'price'): 1,
#  ('price', 'ether'): 1,
#  ('ether', 'surged'): 1,
#  ('surged', 'alltime'): 1,
#  ('alltime', 'high'): 1,
#  ('high', 'friday'): 1,
#  ('friday', 'lockstep'): 1,
#  ('lockstep', 'bitcoins'): 1,
#  ('bitcoins', 'rally'): 1,
#  ('rally', 'shy'): 1,
#  ('shy', 'li'): 1,
#  ('li', 'lately'): 1,
#  ('lately', 'ive'): 1,
#  ('ive', 'taken'): 1,
#  ('taken', 'greatly'): 1,
#  ('greatly', 'epaper'): 1,
#  ('epaper', 'tablet'): 1,
#  ('tablet', 'remarkable'): 1,
#  ('remarkable', 'im'): 1,
#  ('im', 'sure'): 1,
#  ('sure', 'sell'): 1,
#  ('sell', 'apple'): 1,
#  ('apple', 'amazon'): 1,
#  ('amazon', 'slower'): 1,
#  ('slower', 'monochrome'): 1,
#  ('monochrome', 'le'): 1,
#  ('le', 'powerful'): 1,
#  ('powerful', 'ipad'): 1,
#  ('ipad', 'somehow'): 1,
#  ('somehow', 'duller'): 1,
#  ('duller', 'pape'): 1}

# %%
# Use the token_count function to generate the top 10 words from each coin
def token_count(tokens, N=10):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Get the top 10 words for Bitcoin
bitcoin_top_words = token_count(bitcoin_words, N=10)
bitcoin_top_words
# Out:
# [('bitcoin', 17),
#  ('tesla', 7),
#  ('reuters', 7),
#  ('year', 5),
#  ('cryptocurrencies', 4),
#  ('paypal', 3),
#  ('musk', 3),
#  ('crypto', 3),
#  ('investment', 2),
#  ('purchase', 2)]

# %%
# Get the top 10 words for Ethereum
ethereum_top_words = token_count(ethereum_words, N=10)
ethereum_top_words
# Out:
# [('nft', 5),
#  ('cryptocurrency', 5),
#  ('ethereum', 4),
#  ('digital', 4),
#  ('new', 4),
#  ('cryptocurrencies', 3),
#  ('country', 3),
#  ('bitcoin', 3),
#  ('platform', 3),
#  ('nonfungible', 3)]

# %% [markdown]
# # Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
wc = WordCloud()
bitcoin_string = ' '.join(bitcoin_words)
bitcoin_wordcloud = wc.generate(bitcoin_string)
plt.imshow(bitcoin_wordcloud);
plt.title(label="Bitcoin Word Cloud", size=35)
plt.axis("off");

# %%
# Generate the Ethereum word cloud
ethereum_string = ' '.join(ethereum_words)
ethereum_wordcloud = wc.generate(ethereum_string)
plt.imshow(ethereum_wordcloud);
plt.axis("off");
plt.title(label="Ethereum Word Cloud", size=35)
plt.tight_layout(pad=0);

# %% [markdown]
# # Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both coins and visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Optional - download a language model for SpaCy
# !python -m spacy download en_core_web_md
# Out:
# Collecting en-core-web-md==3.0.0
#   Using cached https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.0.0/en_core_web_md-3.0.0-py3-none-any.whl (47.1 MB)
# Requirement already satisfied: spacy<3.1.0,>=3.0.0 in /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from en-core-web-md==3.0.0) (3.0.5)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (52.0.0.post20210125)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (3.7.4.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.1 in /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (2.0.1)
# Requirement already satisfied: numpy>=1.15.0 in /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (1.19.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (3.0.5)
# Requirement already satisfied: importlib-metadata>=0.20 in /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (3.7.3)
# Requirement already satisfied: thinc<8.1.0,>=8.0.2 in /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (8.0.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (2.0.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (4.59.0)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (1.7.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (1.0.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (2.25.1)
# Requirement already satisfied: pathy>=0.3.5 in /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (0.4.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (0.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.0 in /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (3.0.2)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (2.11.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (0.8.2)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (20.9)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (2.4.0)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (0.3.2)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from importlib-metadata>=0.20->spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (3.4.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (2.4.7)
# Requirement already satisfied: smart-open<4.0.0,>=2.2.0 in /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (2.2.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (2.10)
# Requirement already satisfied: boto3 in /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from smart-open<4.0.0,>=2.2.0->pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (1.17.43)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (7.1.2)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from boto3->smart-open<4.0.0,>=2.2.0->pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (0.10.0)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from boto3->smart-open<4.0.0,>=2.2.0->pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (0.3.6)
# Requirement already satisfied: botocore<1.21.0,>=1.20.43 in /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from boto3->smart-open<4.0.0,>=2.2.0->pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (1.20.43)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from botocore<1.21.0,>=1.20.43->boto3->smart-open<4.0.0,>=2.2.0->pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (2.8.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.21.0,>=1.20.43->boto3->smart-open<4.0.0,>=2.2.0->pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages (from jinja2->spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (1.1.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ## Bitcoin NER

# %%
# Concatenate all of the bitcoin text together
bitcoin_text = ''.join(bitcoin_corpus)

# %%
# Run the NER processor on all of the text
bitcoin_ner = nlp(bitcoin_text)

# Add a title to the document
bitcoin_ner.user_data["title"] = "Bitcoin NER"

# %%
# Render the visualization
displacy.render(bitcoin_ner, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Bitcoin NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Whether youre looking to make a larger investment or you just want to dabble in cryptocurrencies, you can purchase
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum, Bitcoin Cash
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Litecoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  through
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PayPal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . And, soon, youll be ab… [+3818 chars]As it promised
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     earlier this year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  now accepts payment in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , according to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# 's website and a tweet from CEO
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Elon Musk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . In a subsequent tweet,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Musk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said that &quot;Bitcoin paid to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  will … [+1390 chars]The inevitable has happened: You can now purchase a
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  vehicle with
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>This is according to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  CEO, pardon,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Technoking Elon Musk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , who tweeted it on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>You can now buy a
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  … [+1648 chars]Tesla made headlines
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     earlier this year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  when it took out significant holdings in bitcoin, acquiring a
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     roughly $1.5 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  stake at then-prices in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     early February
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . At the time, it also noted in an
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SEC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  … [+2071 chars]National
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Burrito Day
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  lands on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     April Fools Day
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this year
#     <span style="font-size: 0.

# %%
# List all Entities
print(bitcoin_ner.user_data["title"])
for ent in bitcoin_ner.ents:
    print(ent.text, ent.label_)
# Out:
# Bitcoin NER
# Bitcoin ORG
# Ethereum, Bitcoin Cash ORG
# Litecoin PERSON
# PayPal ORG
# earlier this year DATE
# Tesla ORG
# Bitcoin ORG
# Tesla ORG
# Elon Musk PERSON
# Musk PERSON
# Tesla ORG
# Tesla ORG
# Bitcoin ORG
# Tesla ORG
# Technoking Elon Musk PERSON
# Wednesday DATE
# Tesla ORG
# earlier this year DATE
# roughly $1.5 billion MONEY
# early February DATE
# SEC ORG
# Burrito Day EVENT
# April Fools Day DATE
# this year DATE
# tomorrow DATE
# Pollo Loco PERSON
# Moes Southwest Grill LOC
# Michele Doying PERSON
# India GPE
# Reuters ORG
# last years DATE
# Twitter PRODUCT
# Graham Ivan Clark PERSON
# India GPE
# Reuters ORG
# a big year DATE
# Robinhood ORG
# today DATE
# Christine Brown PERSON
# Robinhoods PERSON
# Reuters ORG
# Reuters ORG
# Inc ORG
# Monday DATE
# this morning TIME
# Checkout ORG
# millions CARDINAL
# Reuters ORG
# April 12 DATE
# Reuters ORG
# MicroStrategy Inc ORG
# Monday DATE
# Funko PERSON
# NFT ORG
# TokenWave ORG
# Spanish NORP
# AI ORG
# Wise Origin Bitcoin ORG
# the United States GPE
# FD Funds Management LLC ORG
# Reuters ORG
# Bitcoin ORG
# U.S. GPE
# January 8, 2021 DATE
# REUTERS ORG
# Dado Ru PERSON
# Reuters ORG
# U.S. GPE
# January 27, 2020 DATE
# REUTERS ORG
# Dado Ruvic PERSON
# Reu NORP
# Julian Satterthwaite PERSON

# %% [markdown]
# ---

# %% [markdown]
# ## Ethereum NER

# %%
# Concatenate all of the ethereum text together
ethereum_text = ''.join(ethereum_corpus)

# %%
# Run the NER processor on all of the text
ethereum_ner = nlp(ethereum_text)

# Add a title to the document
ethereum_ner.user_data["title"] = "Ethereum NER"

# %%
# Render the visualization
displacy.render(ethereum_ner, style="ent")
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Ethereum NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     One
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>Photo by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Michele Doying
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is reportedly moving forward with a sweeping ban on cryptocurrencies. According to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , the countrys legislat… [+1656 chars]Whether youre looking to make a larger investment or you just want to dabble in cryptocurrencies, you can purchase
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum, Bitcoin Cash
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Litecoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  through
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PayPal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . And, soon, youll be ab… [+3818 chars]Famed auction house
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Christies
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  just sold its
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  purely digital piece of art for a whopping
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $69 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# . For that price, the buyer got a digital file of a collage of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  images and a complex legac… [+12891 chars]Payment card network
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Visa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has announced that transactions can be settled using
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     USD Coin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     USDC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ), a stablecoin powered by the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  blockchain.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Crypto.com
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  company to test the new capabi… [+2187 chars]The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NFT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>That’s what happened at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Roll
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , the social currency platform that allows creators to mint and distribute their own
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>Read the full story here. (And learn even more about NFTs here.)OpenSea has been one of a handful of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NFT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  marketplaces to explode in popularity in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     recent weeks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-lef

# %%
# List all Entities
print(ethereum_ner.user_data["title"])
for ent in ethereum_ner.ents:
    print(ent.text, ent.label_)
# Out:
# Ethereum NER
# One CARDINAL
# Michele Doying PERSON
# India GPE
# Reuters ORG
# Bitcoin ORG
# Ethereum, Bitcoin Cash ORG
# Litecoin PERSON
# PayPal ORG
# Christies ORG
# first ORDINAL
# $69 million MONEY
# 5,000 CARDINAL
# Visa ORG
# USD Coin ORG
# USDC ORG
# Ethereum ORG
# Crypto.com ORG
# first ORDINAL
# NFT ORG
# Roll ORG
# Ethereum ORG
# NFT ORG
# recent weeks DATE
# chars]MetaMask PERSON
# one CARDINAL
# Ethereum ORG
# iOS ORG
# Android ORG
# September 2020 DATE
# Roll ORG
# about $5.7 million MONEY
# a big year DATE
# Robinhood ORG
# today DATE
# Christine Brown PERSON
# Robinhoods PERSON
# Spanish NORP
# AI ORG
# New York Times ORG
# daily DATE
# Topps ORG
# first ORDINAL
# NFT ORG
# The QuantInsti: Quantitative Trading for Beginners Bundle WORK_OF_ART
# 36.32 MONEY
# April 3 DATE
# 90% PERCENT
# hours TIME
# Beeple ORG
# $69 million MONEY
# NFT ORG
# 24 CARDINAL
# 24 CARDINAL
# MLB ORG
# Major League Baseball ORG
# NFT ORG
# Topps ORG
# India GPE
# Reuters ORG
# Hirst PERSON
# Chris Young PERSON
# Damien Hirst PERSON
# Ethereum ORG
# Dado Ruvic PERSON
# Reuters
#  PERSON
# Friday DATE
# 60,000.</li MONEY
# the ReMarkable 2 PRODUCT
# Apple ORG
# Amazon ORG
# iPad ORG
